# %% [markdown]
# # Proyek Pertama : Menyelesaikan Permasalahan Human Resources
#
# - Nama : Usamah Putra Firdaus
# - Email : usamahfirdaa@gmail.com
# - ID Dicoding : Usamah Putra Firdaus

# %% [markdown]
# # **Persiapan**

# %% [markdown]
# ## **Menyiapkan Library**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## **Data Loading**

# %%
# Dataset import from Dicoding GitHub Repository
dataset_url = 'https://raw.githubusercontent.com/dicodingacademy/dicoding_dataset/main/employee/employee_data.csv'

# Read dataset
df = pd.read_csv(dataset_url)
df
# Out:
#       EmployeeId  Age  Attrition     BusinessTravel  DailyRate  \
# 0              1   38        NaN  Travel_Frequently       1444
# 1              2   37        1.0      Travel_Rarely       1141
# 2              3   51        1.0      Travel_Rarely       1323
# 3              4   42        0.0  Travel_Frequently        555
# 4              5   40        NaN      Travel_Rarely       1194
# ...          ...  ...        ...                ...        ...
# 1465        1466   38        0.0      Travel_Rarely        168
# 1466        1467   50        NaN      Travel_Rarely        813
# 1467        1468   28        1.0      Travel_Rarely       1485
# 1468        1469   40        0.0         Non-Travel        458
# 1469        1470   19        1.0  Travel_Frequently        602
#
#                   Department  DistanceFromHome  Education    EducationField  \
# 0            Human Resources                 1          4             Other
# ...

# %% [markdown]
# # **Data Understanding**

# %% [markdown]
# ## **Data Basic Information**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   EmployeeId                1470 non-null   int64
#  1   Age                       1470 non-null   int64
#  2   Attrition                 1058 non-null   float64
#  3   BusinessTravel            1470 non-null   object
#  4   DailyRate                 1470 non-null   int64
#  5   Department                1470 non-null   object
#  6   DistanceFromHome          1470 non-null   int64
#  7   Education                 1470 non-null   int64
#  8   EducationField            1470 non-null   object
#  9   EmployeeCount             1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# Berikut adalah penjelasan tiap variablenya:
#
# - **EmployeeId** – ID unik untuk masing-masing karyawan.
#
# - **Attrition** – Apakah karyawan keluar dari perusahaan? (0 = tidak, 1 = ya).
#
# - **Age** – Usia karyawan.
#
# - **BusinessTravel** – Frekuensi perjalanan dinas dalam pekerjaan.
#
# - **DailyRate** – Gaji harian karyawan.
#
# - **Department** – Departemen tempat karyawan bekerja.
#
# - **DistanceFromHome** – Jarak rumah ke tempat kerja (dalam kilometer).
#
# - **Education** – Tingkat pendidikan:
# 1 = Di bawah Perguruan Tinggi,
# 2 = Perguruan Tinggi,
# 3 = Sarjana,
# 4 = Magister,
# 5 = Doktor.
#
# - **EducationField** – Bidang studi pendidikan terakhir karyawan.
#
# - **EnvironmentSatisfaction** – Kepuasan terhadap lingkungan kerja:
# 1 = Rendah,
# 2 = Sedang,
# 3 = Tinggi,
# 4 = Sangat Tinggi.
#
# - **Gender** – Jenis kelamin karyawan.
#
# - **HourlyRate** – Gaji per jam.
#
# - **JobInvolvement** – Tingkat keterlibatan dalam pekerjaan:
# 1 = Rendah,
# 2 = Sedang,
# 3 = Tinggi,
# 4 = Sangat Tinggi.
#
# - **JobLevel** – Level atau tingkatan pekerjaan (1 sampai 5).
#
# - **JobRole** – Jabatan atau peran pekerjaan karyawan.
#
# - **JobSatisfaction** – Kepuasan terhadap pekerjaan:
# 1 = Rendah,
# 2 = Sedang,
# 3 = Tinggi,
# 4 = Sangat Tinggi.
#
# - **MaritalStatus** – Status pernikahan (Lajang, Menikah, atau Bercerai).
#
# - **MonthlyIncome** – Gaji bulanan karyawan.
#
# - **MonthlyRate** – Tarif atau gaji yang dihitung secara bulanan.
#
# - **NumCompaniesWorked** – Jumlah perusahaan yang pernah menjadi tempat kerja karyawan.
#
# - **Over18** – Apakah usia karyawan di atas 18 tahun? (biasanya "Y" = Ya).
#
# - **OverTime** – Apakah karyawan bekerja lembur? (Ya atau Tidak).
#
# - **PercentSalaryHike** – Persentase kenaikan gaji selama satu tahun terakhir.
#
# - **PerformanceRating** – Penilaian kinerja:
# 1 = Rendah,
# 2 = Baik,
# 3 = Sangat Baik,
# 4 = Luar Biasa.
#
# - **RelationshipSatisfaction** – Kepuasan terhadap hubungan kerja dengan rekan atau atasan:
# 1 = Rendah,
# 2 = Sedang,
# 3 = Tinggi,
# 4 = Sangat Tinggi.
#
# - **StandardHours** – Jam kerja standar (biasanya konstan untuk semua karyawan).
#
# - **StockOptionLevel** – Tingkat opsi saham yang diberikan perusahaan kepada karyawan.
#
# - **TotalWorkingYears** – Total tahun pengalaman kerja.
#
# - **TrainingTimesLastYear** – Jumlah pelatihan yang diikuti tahun lalu.
#
# - **WorkLifeBalance** – Keseimbangan antara pekerjaan dan kehidupan pribadi:
# 1 = Rendah,
# 2 = Baik,
# 3 = Sangat Baik,
# 4 = Luar Biasa.
#
# - **YearsAtCompany** – Lama bekerja di perusahaan saat ini (dalam tahun).
#
# - **YearsInCurrentRole** – Lama berada di posisi atau jabatan saat ini (dalam tahun).
#
# - **YearsSinceLastPromotion** – Lama waktu sejak promosi terakhir (dalam tahun).
#
# - **YearsWithCurrManager** – Lama bekerja dengan atasan/manajer saat ini (dalam tahun).

# %% [markdown]
# Dapat diketahui bahwa feature `Attrition` datanya adalah 1 dan 0, namun tipe datanya float, sehingga perlu diubah ke int

# %%
df.isnull().sum()
# Out:
# EmployeeId                    0
# Age                           0
# Attrition                   412
# BusinessTravel                0
# DailyRate                     0
# Department                    0
# DistanceFromHome              0
# Education                     0
# EducationField                0
# EmployeeCount                 0
# EnvironmentSatisfaction       0
# Gender                        0
# HourlyRate                    0
# JobInvolvement                0
# JobLevel                      0
# JobRole                       0
# JobSatisfaction               0
# MaritalStatus                 0
# MonthlyIncome                 0
# MonthlyRate                   0
# NumCompaniesWorked            0
# Over18                        0
# OverTime                      0
# PercentSalaryHike             0
# PerformanceRating             0
# RelationshipSatisfaction      0
# StandardHours                 0
# StockOptionLevel              0
# TotalWorkingYears             0
# ...

# %% [markdown]
# Terdapat 412 missing value pada feature `Attrition`

# %%
print('Jumlah data terduplikat: ', df.duplicated().sum())
# Out:
# Jumlah data terduplikat:  0

# %%
df.describe()
# Out:
#         EmployeeId          Age    Attrition    DailyRate  DistanceFromHome  \
# count  1470.000000  1470.000000  1058.000000  1470.000000       1470.000000
# mean    735.500000    36.923810     0.169187   802.485714          9.192517
# std     424.496761     9.135373     0.375094   403.509100          8.106864
# min       1.000000    18.000000     0.000000   102.000000          1.000000
# 25%     368.250000    30.000000     0.000000   465.000000          2.000000
# 50%     735.500000    36.000000     0.000000   802.000000          7.000000
# 75%    1102.750000    43.000000     0.000000  1157.000000         14.000000
# max    1470.000000    60.000000     1.000000  1499.000000         29.000000
#
#          Education  EmployeeCount  EnvironmentSatisfaction   HourlyRate  \
# count  1470.000000         1470.0              1470.000000  1470.000000
# mean      2.912925            1.0                 2.721769    65.891156
# ...

# %%
df.describe(include='object')
# Out:
#        BusinessTravel              Department EducationField Gender  \
# count            1470                    1470           1470   1470
# unique              3                       3              6      2
# top     Travel_Rarely  Research & Development  Life Sciences   Male
# freq             1043                     961            606    882
#
#                 JobRole MaritalStatus Over18 OverTime
# count              1470          1470   1470     1470
# unique                9             3      1        2
# top     Sales Executive       Married      Y       No
# freq                326           673   1470     1054

# %% [markdown]
# Dari hasil data diskriptif diatas, feature `EmployeeCount` dan `Over18` hanya memiliki 1 data unik. Jadi kita dapat menghapus kedua feature tersebut, karena kedua feature ini tidak berpengaruh dalam permasalahan bisnis

# %%
df.shape
# Out:
# (1470, 35)

# %% [markdown]
# ## **Data Cleaning**

# %% [markdown]
# ### **Handling Missing Value**

# %% [markdown]
# Karena feature `Attrition` merupakan data utama dalam permasalahan bisnis, dan tidak bisa dilakukan inputing sembarangan, sehingga kita hapus saja nilai yang kosong

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# EmployeeId                  0
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# ### **Mengubah Tipe Data**

# %%
df['Attrition'] = df['Attrition'].astype(int)
df['Attrition'].dtypes
# Out:
# dtype('int64')

# %% [markdown]
# ### **Menghapus Kolom yang tidak digunakan**

# %%
df = df.drop(['Over18', 'EmployeeCount'], axis=1)
df
# Out:
#       EmployeeId  Age  Attrition     BusinessTravel  DailyRate  \
# 1              2   37          1      Travel_Rarely       1141
# 2              3   51          1      Travel_Rarely       1323
# 3              4   42          0  Travel_Frequently        555
# 6              7   40          0      Travel_Rarely       1124
# 7              8   55          1      Travel_Rarely        725
# ...          ...  ...        ...                ...        ...
# 1464        1465   28          1         Non-Travel       1366
# 1465        1466   38          0      Travel_Rarely        168
# 1467        1468   28          1      Travel_Rarely       1485
# 1468        1469   40          0         Non-Travel        458
# 1469        1470   19          1  Travel_Frequently        602
#
#                   Department  DistanceFromHome  Education    EducationField  \
# 1     Research & Development                11          2           Medical
# ...

# %% [markdown]
# ## **Ordinal Encoding**

# %% [markdown]
# Pada feature `Education`, `EnvironmentSatisfaction`, `JobInvolvement`, `JobSatisfaction`, `PerformanceRating`, `RelationshipSatisfaction`, dan `WorkLifeBalance`. Kita harus mengubahnya ke kategorikal agar lebih mudah untuk menyelesaikan permasalahan bisnis

# %%
def ordinal_decoding(df, feature):
    if feature == 'Attrition':
        category = {0: 'No', 1: 'Yes'}
        df[feature] = df[feature].map(category)
    elif feature == 'Education':
        category = {1: 'Below College', 2: 'College', 3: 'Bachelor',
                    4: 'Master', 5: 'Doctor'}
        df[feature] = df[feature].map(category)
    elif feature in ['WorkLifeBalance', 'PerformanceRating']:
        category = {1: 'Low', 2: 'Good', 3: 'Excellent', 4: 'Outstanding'}
        df[feature] = df[feature].map(category)
    else:
        category = {1: 'Low', 2: 'Medium', 3: 'High', 4: 'Very High'}
        for f in feature:
            df[f] = df[f].map(category)

    return df

# %%
df = ordinal_decoding(df, 'Attrition')
df = ordinal_decoding(df, 'Education')
df = ordinal_decoding(df, ['EnvironmentSatisfaction', 'JobInvolvement',
                           'JobSatisfaction', 'RelationshipSatisfaction'])
df = ordinal_decoding(df, ['PerformanceRating', 'WorkLifeBalance'])

df
# Out:
#       EmployeeId  Age Attrition     BusinessTravel  DailyRate  \
# 1              2   37       Yes      Travel_Rarely       1141
# 2              3   51       Yes      Travel_Rarely       1323
# 3              4   42        No  Travel_Frequently        555
# 6              7   40        No      Travel_Rarely       1124
# 7              8   55       Yes      Travel_Rarely        725
# ...          ...  ...       ...                ...        ...
# 1464        1465   28       Yes         Non-Travel       1366
# 1465        1466   38        No      Travel_Rarely        168
# 1467        1468   28       Yes      Travel_Rarely       1485
# 1468        1469   40        No         Non-Travel        458
# 1469        1470   19       Yes  Travel_Frequently        602
#
#                   Department  DistanceFromHome      Education  \
# 1     Research & Development                11        College
# 2     Research & Development                 4         Master
# ...

# %%
df.to_csv('cleaned_df.csv', index=False)

# %% [markdown]
# ## **Exploratory Data Analysis**

# %% [markdown]
# ### **Univariate Analysis**

# %%
numerical, categorical = [], []

for feature in df.columns:
    if df[feature].dtype != 'object':
        numerical.append(feature)
    else:
        categorical.append(feature)

# %% [markdown]
# #### **Numerical Analysis**

# %%
df[numerical].hist(bins=15, figsize=(18, 16))
plt.show()

# %% [markdown]
# Berdasarkan grafik tersebut, terlihat bahwa beberapa fitur numerik memiliki distribusi yang miring ke kanan (right-skewed distribution), contohnya `DistanceFromHome`, `MonthlyIncome`, `NumCompaniesWorked`, `PercentageSalaryHike`, `TotalWorkingYears`, `YearsAtCompany`, `YearsCurrentRole`, `YearsSinceLastPromotion`, dan `YearsWithCurrManager`. Sementara itu, fitur `Age` dan `TrainingTimeLastYear` menunjukkan distribusi yang normal.

# %% [markdown]
# #### **Categorical Analysis**

# %%
fig, ax = plt.subplots(3, 5, figsize=(24, 14))
for i, feature in enumerate(categorical):
    row = i // 5
    col = i % 5
    sns.countplot(data=df, x=feature, ax=ax[row, col], hue=feature, palette='Set2')
    ax[row, col].set_title(feature, fontsize=10)
    ax[row, col].set_xlabel('')

    for bar in ax[row, col].patches:
        ax[row, col].annotate(
            str(int(bar.get_height())),
            (bar.get_x() + bar.get_width() / 2, bar.get_height() - (bar.get_height() * 0.05)),
            ha='center', va='top', fontsize=10, color='black', weight='bold')

    for label in ax[row, col].get_xticklabels():
        label.set_rotation(90)

for j in range(len(categorical), 15):
    fig.delaxes(ax[j // 5, j % 5])

plt.subplots_adjust(hspace=1.2, wspace=0.3)
plt.show()

# %% [markdown]
# **Interpretasi**:
#
# - Jumlah karyawan paling banyak pada departemen Research & Development
# - Karyawan yang memiliki gelar Doctor sangat sedikit
# - Sebagian besar karyawan berasal dari bidang pendidikan Life Science
# - Mayoritas karyawan memiliki peran pekerjaan sebagai Sales Executive.
# - Jumlah karyawan yang tidak lembur lebih banyak daripada yang lembur
# - Sebagian besar karyawan jarang melakukan perjalanan dinas (Travel Rarely)
# - Sebagian besar karyawan berstatus menikah
# - Secara umum, karyawan memiliki kepuasan tinggi terhadap lingkungan kerja, hubungan kerja yang baik, sangat terlibat dalam pekerjaan, dan memiliki kinerja yang tinggi
# - Mayoritas karyawan memiliki Work Life Balance yang sangat baik

# %% [markdown]
# ### **Multivariate Analysis**

# %% [markdown]
# #### **Numerical Analysis**

# %%
def numerical_dis_plot(features, df, segment_feature=None, showfliers=True):
    fig, ax = plt.subplots(2, 2, figsize=(15, 8))
    for i, feature in enumerate(features):
        row = i // 2
        col = i % 2
        if segment_feature:
            sns.boxplot(y=segment_feature, x=feature, data=df, ax=ax[row, col], showfliers=showfliers)
            ax[row, col].set_title(f'{segment_feature} Distribution Plot Based on {feature}')
        else:
            sns.boxplot(x=feature, data=df, ax=ax[row, col], showfliers=showfliers)
            ax[row, col].set_title(f'{feature} Distribution Plot')

        ax[row, col].set_ylabel(None)

    plt.tight_layout()
    plt.show()

# %%
numerical_dis_plot(
    features=['Age', 'TotalWorkingYears', 'MonthlyIncome', 'MonthlyRate'],
    df=df,
    segment_feature='Education'
)

# %%
numerical_dis_plot(
    features=['Age', 'DistanceFromHome', 'JobLevel', 'MonthlyIncome'],
    df=df,
    segment_feature='JobRole'
)

# %%
numerical_dis_plot(
    features=['TotalWorkingYears', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsWithCurrManager'],
    df=df,
    segment_feature='JobRole'
)

# %% [markdown]
# #### **Categorical Analysis**

# %%
def categorical_dis_plot(features, df, segment_feature=None):
    fig, ax = plt.subplots(len(features), 1, figsize=(16, 18))
    for i, feature in enumerate(features):
        if segment_feature:
            sns.countplot(data=df, x=segment_feature, hue=feature, ax=ax[i])
            ax[i].set_title(f'{segment_feature} Distribution Plot Based on {feature}')
        else:
            sns.countplot(data=df, x=feature, ax=ax[i])
            ax[i].set_title(f'{feature} Distribution Plot')

        for bar in ax[i].patches:
            ax[i].annotate(
                str(int(bar.get_height())),
                (bar.get_x() + bar.get_width() / 2, bar.get_height()),
                ha='center', va='bottom', fontsize=10)

        ax[i].set_ylabel(None)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# Distribusi data berdasarkan `JobRole`

# %%
categorical_dis_plot(
    features=['Gender', 'Education', 'EducationField', 'MaritalStatus'],
    df=df,
    segment_feature='JobRole'
)

# %%
categorical_dis_plot(
    features=['OverTime', 'PerformanceRating', 'RelationshipSatisfaction', 'WorkLifeBalance'],
    df=df,
    segment_feature='JobRole'
)

# %% [markdown]
# Distribusi data berdasarkan `Departement`

# %%
categorical_dis_plot(
    features=['Gender', 'Education', 'EducationField', 'MaritalStatus'],
    df=df,
    segment_feature='Department'
)

# %%
categorical_dis_plot(
    features=['OverTime', 'PerformanceRating', 'RelationshipSatisfaction', 'WorkLifeBalance'],
    df=df,
    segment_feature='Department'
)

# %% [markdown]
# #### **Attrition Comparation Analysis**

# %%
ax = df['Attrition'].value_counts().plot(kind='bar')
ax.set_ylabel('Count')

for bar in ax.patches:
    ax.annotate(str(bar.get_height()),
                (bar.get_x() + bar.get_width() / 2, bar.get_height()),
                ha='center', va='bottom', fontsize=10)

# %% [markdown]
# Berdasarkan visualisasi diatas, sebanyak 179 karyawan -+ 10% dari total karyawan melakukan attrition atau keluar dari perusahaan

# %%
# Melakukan binning pada kolom 'Age'
bins = [18, 30, 40, 50, 60]
labels = ['18-30', '31-40', '41-50', '51-60']
df['Age_binned'] = pd.cut(df['Age'], bins=bins, labels=labels, right=True, include_lowest=True)

# Menggunakan kolom hasil binning di plot
categorical_dis_plot(
    features=['Age_binned', 'JobRole', 'JobInvolvement', 'JobLevel'],
    df=df,
    segment_feature='Attrition'
)

# %% [markdown]
# # Export Requirement

# %%
# !pip freeze > requirements.txt
